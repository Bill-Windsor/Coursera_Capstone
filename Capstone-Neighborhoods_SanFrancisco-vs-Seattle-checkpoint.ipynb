# %% [markdown]
# # IBM Data Science: Capstone Project
# ## Battle of the Neighborhoods - Week 1
# ## William Windsor
# **+++++++++++++**
# ### Battle of the Neighborhoods -- Business Decision:
# ### Where to Locate a Professional Services Business: San Francisco SoMa Area or Seattle Pioneer Square?

# %% [markdown]
# **+++++++++++++**
# ### Part 1: Description of the Problem and a Discussion of the Background
# #### Business Problem to Be Addressed: this data science project will address the decision where to locate a professional services business that services a geographical concentration of high tech companies that includes a burgeoning high-tech startup hub.
# #### Examples of professional services businesses could be providing data science and data research services to tech companies (such as motivated by this IBM Data Science Professional Certification program!); facilities planning and facilities location research services;  professional human resources contract services;  professional legal services; on-site health care and monitoring services; or security services such as IT software hosting and security or personnel for on-site security monitoring.
# #### This project will focus on two neighborhoods:
# ####   * San Francisco, CA: SoMa (South of Market Street) region
# ####   * Seattle, WA: Pioneer Square region
# #### Both of these geographical regions have strong technology company presence, and both are noted for their burgeoning increase of technology startup companies.
# ### Target Audience and Why They Would Care About This Problem:
# #### The target audience for this study are CEOs and entrepreneurs and venture capital companies looking to evaluate where to establish a new professional services business. They would care about this data analysis because the study will provide data sources and data science evaluation for several factors important for locating the business, with the thrust that professional services businesses generate greater success when they are located near their client field.

# %% [markdown]
# **+++++++++++++**
# ### Part 2: Description of the Data and How It Will Be Used to Solve the Problem
# #### Decision Methodology and Datasets Planned to Be Used: the decision of where to locate a professional services business servicing a high-tech company hub depends on many factors. In this study, I focus on two major sets of factors:
# ####   (1) Financial impact to the company;  (2) Employee quality of life.

# %% [markdown]
# ### (1) Financial Impact: the study integrates financial costs and impact of locating in each area, focusing on:
# ###   (a) Commercial Office Real Estate lease and rent costs, based on current commercial office properties available at the time of this study.
# ####    These datasets, one for each city and locale, will be structured in the following fields for comparison: Property Address, Neighborhood or Zip Code, Rental Price per Month, Property Area in square feet, Price per Square Foot.
# #### I utilize the following commercial real estate companies' websites to extract these targeted commercial property data. The sites below provide these data for San Francisco and Seattle commercial properties:
# #### https://www.loopnet.com ,  https://www.cityfeet.com ,  https://42floors.com

# %% [markdown]
# ###   (b) Business density concentration, utilizing the Foursquare dataset.
# #### This section of the study will prioritize the highest density of businesses in each neighborhood (highest numerical concentration of businesses), in order to determine a higher judgment of success in reaching businesses closely located to our proposed business.
# #### I utilize Foursquare to generate the number of business venues within a 1-mile radius of each targeted locality,  then use venue grouping and cluster density machine learning to generate the region with the highest density of businesses, between San Francisco / SoMa and Seattle / Pioneer Square regions.
# ###   (c) Business Taxes
# #### To document the financial impact of business taxes, I utilize the following governmental organizations to extract business tax rate as a percent, to locate the professional services business in either San Francisco, CA or Seattle, WA. The sites below provide these data for their respective location:
# ####    * San Francisco city and State of California business taxes:  https://sftreasurer.org/business ,  https://www.ftb.ca.gov/businesses/index.shtml
# ####    * Seattle city and State of Washington business taxes:  https://www.seattle.gov/business-licenses-and-taxes ,  https://dor.wa.gov/find-taxes-rates/business-occupation-tax

# %% [markdown]
# ### (2) Employee Quality of Life, utilizing the Foursquare dataset.
# #### Utilizing the Foursquare venues data, I utilize the Foursquare dataset to analyze local venues providing increased quality of life in the vicinity. "Quality of life" is clearly a subjective concept. So I have selected the following three factors affecting quality of life from the Foursquare data:
# ####    (a) Availability of Public Transportation: specify how many subway public transportation stations are located in each region, and the distance of each from the center of each neighborhood.
# ####    (b) Availability of Exercise Facilities: specify how many gyms or exercise facilities are located in each region.
# ####    (c) Availability of Restaurants: specify how many restaurants are located in each region.
# **+++++++++++++**
# ### Below is the start of this work, to extract the Foursquare venues data for each location: San Francisco / SoMa and Seattle / Pioneer Square regions.

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.cm as cm
import matplotlib.colors as colors

import requests
from bs4 import BeautifulSoup
import csv
import xml
import random          # library for random number generation
print("Initial packages imported: \nNumPy, Pandas, Matplotlib, Requests, bs4.BeautifulSoup, CSV, XML, Random.")
# Out:
# Initial packages imported:
# NumPy, Pandas, Matplotlib, Requests, bs4.BeautifulSoup, CSV, XML, Random.

# %%
import json 
# Tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# module to convert an address into latitude and longitude values
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim 
print("GeoPy.Geocoders.Nominatim installed.")

# Libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
print("IPython Image and HTML installed.")

from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes
import folium 
from folium import plugins

print("Second set of libraries imported: \nJSON, JSON_Normalize, Nominatum, Image, HTML, KMeans, Folium.")
# Out:
# GeoPy.Geocoders.Nominatim installed.
# IPython Image and HTML installed.
# Second set of libraries imported:
# JSON, JSON_Normalize, Nominatum, Image, HTML, KMeans, Folium.

# %%
# Specify Location (Latitude and Longitude Coordinates) of:
#  San Francisco / SoMa Area (South of Market Street): AddressSFSoMa
#  Seattle / Pioneer Square Area: AddressSeattlePS

AddressSFSoMa = 'San Francisco, CA / SoMa Area'
#location_SFSoMa = getlocation(AddressSFSoMa)
latitude_SFSoMa = 37.775316
longitude_SFSoMa = -122.419626

AddressSeattlePS = 'Seattle, WA / Pioneer Square Area'
#location_SeattlePS = getlocation(AddressSeattlePS)
latitude_SeattlePS = 47.601954
longitude_SeattlePS = -122.329204

print('The geographical coordinates of', AddressSFSoMa, 'are    : {}  {}'.format(latitude_SFSoMa, longitude_SFSoMa))
print('The geographical coordinates of', AddressSeattlePS, 'are: {}  {}'.format(latitude_SeattlePS, longitude_SeattlePS))
# Out:
# The geographical coordinates of San Francisco, CA / SoMa Area are    : 37.775316  -122.419626
# The geographical coordinates of Seattle, WA / Pioneer Square Area are: 47.601954  -122.329204

# %%
# Display map of the region to show the two cities
map_all = folium.Map(location=[(latitude_SFSoMa+latitude_SeattlePS)/2, ((longitude_SFSoMa+longitude_SeattlePS)/2)+5], tiles='Stamen Terrain', zoom_start=5)

folium.Marker(location=[latitude_SFSoMa, longitude_SFSoMa], popup='San Francisco').add_to(map_all)
folium.CircleMarker(location=[latitude_SFSoMa, longitude_SFSoMa], radius=10,
popup='San Francisco / SoMa Area', color='#3186cc', fill_color='#3186cc').add_to(map_all)

folium.Marker(location=[latitude_SeattlePS, longitude_SeattlePS], popup='Seattle').add_to(map_all)
folium.CircleMarker(location=[latitude_SeattlePS, longitude_SeattlePS], radius=10,
popup='Seattle / Pioneer Square', color='#3186cc', fill_color='#3186cc').add_to(map_all)

map_all
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Display map of the San Francisco / SoMa Area (South of Market Street)
map_SFSoMa = folium.Map(location=[latitude_SFSoMa, longitude_SFSoMa], tiles='Stamen Terrain', zoom_start=12)

folium.Marker(location=[latitude_SFSoMa, longitude_SFSoMa], popup='San Francisco').add_to(map_SFSoMa)
folium.CircleMarker(location=[latitude_SFSoMa, longitude_SFSoMa], radius=10,
popup='San Francisco / SoMa Area', color='#3186cc', fill_color='#3186cc').add_to(map_SFSoMa)

map_SFSoMa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Please Note: this is the cell where I provide my Foursquare confidential customer credentials
# My Foursquare confidential customer credentials are REDACTED here.

# %%
# San Francisco / SoMa area:
# Analyze venues / local businesses within 1500 meters of the target neighborhood (approx. 1 mile radius)
radius = 1500
limit = 100
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, VERSION, latitude_SFSoMa, longitude_SFSoMa, radius, limit)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=0L5LJUZ1ZRIICXKIV3JEBXMSIR2A2WUKTL2PYY2UE22TX5DL&client_secret=OE2B2ZNPTMOQCWJATIXF1IBTKWIMPZT5Q3OO0PE2LBPN0UFI&v=20180605&ll=37.775316,-122.419626&radius=1500&limit=100'

# %%
results = requests.get(url).json()

# results

# Test selected objects and venues from the dataset - focus on the 'items' object
# print("meta: requestId: ", results['meta']['requestId'])
# print("response: suggestedBounds: 'ne', 'sw' \n", results['response']['suggestedBounds']['ne'], '\n', results['response']['suggestedBounds']['sw'])
results['response']['groups'][0]['items']
# Out:
# [{'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '50f21340e4b036c5cc0d7c7d',
#    'name': 'SFJazz Center',
#    'location': {'address': '201 Franklin St',
#     'crossStreet': 'at Fell St',
#     'lat': 37.77635001768186,
#     'lng': -122.42153942584991,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.77635001768186,
#       'lng': -122.42153942584991}],
#     'distance': 203,
#     'postalCode': '94102',
#     'cc': 'US',
#     'neighborhood': 'Civic Center',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['201 Franklin St (at Fell St)',
#      'San Francisco, CA 94102',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1e7931735',
#      'name': 'Jazz Club',
#      'pluralName': 'Jazz Clubs',
#      'shortName': 'Jazz Club',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_jazzclub_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-50f21340e4b036c5cc0d7c7d-0'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4a346043f964a520279c1fe3',
#    'name': 'New Conservatory Theatre Center',
#    'location': {'address': '25 Van Ness Ave',
#     'crossStreet': 'Oak St',
#     'lat': 37.775591039720815,
#     'lng': -122.419753074646,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.775591039720815,
#       'lng': -122.419753074646}],
#     'distance': 32,
#     'postalCode': '94102',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['25 Van Ness Ave (Oak St)',
#      'San Francisco, CA 94102',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d137941735',
#      'name': 'Theater',
#      'pluralName': 'Theaters',
#      'shortName': 'Theater',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '75569151'}},
#   'referralId': 'e-0-4a346043f964a520279c1fe3-1'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '5560dbdb498e91a2bcde84f6',
#    'name': 'Blue Bottle Coffee',
#    'location': {'address': '1355 Market St Ste 190',
#     'crossStreet': 'at 10th St',
#     'lat': 37.77628641647586,
#     'lng': -122.41686701774597,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.77628641647586,
#       'lng': -122.41686701774597}],
#     'distance': 265,
#     'postalCode': '94103',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['1355 Market St Ste 190 (at 10th St)',
#      'San Francisco, CA 94103',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1e0931735',
#      'name': 'Coffee Shop',
#      'pluralName': 'Coffee Shops',
#      'shortName': 'Coffee Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-5560dbdb498e91a2bcde84f6-2'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4d8eabc7d265236af9a71017',
#    'name': 'Nojo Ramen Tavern',
#    'location': {'address': '231 Franklin St',
#     'crossStreet': 'at Linden St',
#     'lat': 37.776636596637324,
#     'lng': -122.42127005612625,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.776636596637324,
#       'lng': -122.42127005612625}],
#     'distance': 206,
#     'postalCode': '94102',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['231 Franklin St (at Linden St)',
#      'San Francisco, CA 94102',
#      'United States']},
#    'categories': [{'id': '55a59bace4b013909087cb24',
#      'name': 'Ramen Restaurant',
#      'pluralName': 'Ramen Restaurants',
#      'shortName': 'Ramen',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4d8eabc7d265236af9a71017-3'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '5600850a498edff486fdfe89',
#    'name': 'Cala',
#    'location': {'address': '149 Fell St',
#     'crossStreet': 'btwn Franklin and Van Ness',
#     'lat': 37.77606310699734,
#     'lng': -122.42038628873841,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.77606310699734,
#       'lng': -122.42038628873841}],
#     'distance': 106,
#     'postalCode': '94102',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['149 Fell St (btwn Franklin and Van Ness)',
#      'San Francisco, CA 94102',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1c1941735',
#      'name': 'Mexican Restaurant',
#      'pluralName': 'Mexican Restaurants',
#      'shortName': 'Mexican',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-5600850a498edff486fdfe89-4'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '515a3fa1e4b0d8e060562071',
#    'name': 'Sydney Goldstein Theater',
#    'location': {'address': '275 Hayes St',
#     'crossStreet': 'at Franklin St',
#     'lat': 37.77703051397989,
#     'lng': -122.42097920444503,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.77703051397989,
#       'lng': -122.42097920444503}],
#     'distance': 224,
#     'postalCode': '94102',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['275 Hayes St (at Franklin St)',
#      'San Francisco, CA 94102',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1f2931735',
#      'name': 'Performing Arts Venue',
#      'pluralName': 'Performing Arts Venues',
#      'shortName': 'Performing Arts',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-515a3fa1e4b0d8e060562071-5'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4aa48566f964a520024720e3',
#    'name': 'Louise M. Davies Symphony Hall',
#    'location': {'address': '201 Van Ness Ave',
#     'crossStreet': 'btwn Grove & Hayes St',
#     'lat': 37.7779761642689,
#     'lng': -122.42015694896058,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.7779761642689,
#       'lng': -122.42015694896058}],
#     'distance': 299,
#     'postalCode': '94102',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['201 Van Ness Ave (btwn Grove & Hayes St)',
#      'San Francisco, CA 94102',
#      'United States']},
#    'categories': [{'id': '5032792091d4c4b30a586d5c',
#      'name': 'Concert Hall',
#      'pluralName': 'Concert Halls',
#      'shortName': 'Concert Hall',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4aa48566f964a520024720e3-6'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4c996073db10b60cdde7896d',
#    'name': 'Fatted Calf',
#    'location': {'address': '320 Fell St',
#     'crossStreet': 'at Gough St',
#     'lat': 37.77593518054966,
#     'lng': -122.42314601183367,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.77593518054966,
#       'lng': -122.42314601183367}],
#     'distance': 317,
#     'postalCode': '94102',
#     'cc': 'US',
#     'neighborhood': 'Hayes Valley',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['320 Fell St (at Gough St)',
#      'San Francisco, CA 94102',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d11d951735',
#      'name': 'Butcher',
#      'pluralName': 'Butchers',
#      'shortName': 'Butcher',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_butcher_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4c996073db10b60cdde7896d-7'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '43fb0c0ef964a520df2f1fe3',
#    'name': 'Hotel Biron',
#    'location': {'address': '45 Rose St',
#     'crossStreet': 'at Market St.',
#     'lat': 37.77350386431412,
#     'lng': -122.42211040391679,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.77350386431412,
#       'lng': -122.42211040391679}],
#     'distance': 297,
#     'postalCode': '94102',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['45 Rose St (at Market St.)',
#      'San Francisco, CA 94102',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d123941735',
#      'name': 'Wine Bar',
#      'pluralName': 'Wine Bars',
#      'shortName': 'Wine Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-43fb0c0ef964a520df2f1fe3-8'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '519fcb37498e91a13cb23d6b',
#    'name': 'The Beer Hall',
#    'location': {'address': '1 Polk St',
#     'crossStreet': 'at Market St',
#     'lat': 37.77683728951549,
#     'lng': -122.41791582317194,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.77683728951549,
#       'lng': -122.41791582317194}],
#     'distance': 226,
#     'postalCode': '94102',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['1 Polk St (at Market St)',
#      'San Francisco, CA 94102',
#      'United States']},
#    'categories': [{'id': '56aa371ce4b08b9a8d57356c',
#      'name': 'Beer Bar',
#      'pluralName': 'Beer Bars',
#      'shortName': 'Beer Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '65160250'}},
#   'referralId': 'e-0-519fcb37498e91a13cb23d6b-9'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '500088f7d63e64b62bc19e6e',
#    'name': 'Rich Table',
#    'location': {'address': '199 Gough St',
#     'crossStreet': 'at Oak St',
#     'lat': 37.774891,
#     'lng': -122.422736,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.774891,
#       'lng': -122.422736}],
#     'distance': 277,
#     'postalCode': '94102',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['199 Gough St (at Oak St)',
#      'San Francisco, CA 94102',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d157941735',
#      'name': 'New American Restaurant',
#      'pluralName': 'New American Restaurants',
#      'shortName': 'New American',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '52310779'}},
#   'referralId': 'e-0-500088f7d63e64b62bc19e6e-10'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '53d7d522498e54a8e8fec844',
#    'name': 'Fitness SF',
#    'location': {'address': '1 10th St',
#     'crossStreet': 'Market St',
#     'lat': 37.77631321074178,
#     'lng': -122.41664540168138,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.77631321074178,
#       'lng': -122.41664540168138}],
#     'distance': 284,
#     'postalCode': '94103',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['1 10th St (Market St)',
#      'San Francisco, CA 94103',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d175941735',
#      'name': 'Gym / Fitness Center',
#      'pluralName': 'Gyms or Fitness Centers',
#      'shortName': 'Gym / Fitness',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-53d7d522498e54a8e8fec844-11'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '516875d9e4b08299c609c0d7',
#    'name': 'Veer & Wander',
#    'location': {'address': '6 Brady St',
#     'lat': 37.77340210312653,
#     'lng': -122.4209958352376,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.77340210312653,
#       'lng': -122.4209958352376}],
#     'distance': 244,
#     'postalCode': '94103',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['6 Brady St',
#      'San Francisco, CA 94103',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d110951735',
#      'name': 'Salon / Barbershop',
#      'pluralName': 'Salons / Barbershops',
#      'shortName': 'Salon / Barbershop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '405498914'}},
#   'referralId': 'e-0-516875d9e4b08299c609c0d7-12'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '43d3901ef964a5201f2e1fe3',
#    'name': 'Blue Bottle Coffee',
#    'location': {'address': '315 Linden St',
#     'crossStreet': 'btwn Gough & Octavia St',
#     'lat': 37.776430131820725,
#     'lng': -122.42322360122202,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.776430131820725,
#       'lng': -122.42322360122202}],
#     'distance': 339,
#     'postalCode': '94102',
#     'cc': 'US',
#     'neighborhood': 'Hayes Valley',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['315 Linden St (btwn Gough & Octavia St)',
#      'San Francisco, CA 94102',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1e0931735',
#      'name': 'Coffee Shop',
#      'pluralName': 'Coffee Shops',
#      'shortName': 'Coffee Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-43d3901ef964a5201f2e1fe3-13'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '55346c03498e56b57395abc1',
#    'name': 'Siam Orchid Traditional Thai Massage',
#    'location': {'address': '39 Polk St',
#     'lat': 37.77711106486655,
#     'lng': -122.41796702789824,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.77711106486655,
#       'lng': -122.41796702789824}],
#     'distance': 247,
#     'postalCode': '94102',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['39 Polk St',
#      'San Francisco, CA 94102',
#      'United States']},
#    'categories': [{'id': '52f2ab2ebcbc57f1066b8b3c',
#      'name': 'Massage Studio',
#      'pluralName': 'Massage Studios',
#      'shortName': 'Massage Studio',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-55346c03498e56b57395abc1-14'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '5473635d498e14e5b792756d',
#    'name': 'Warby Parker',
#    'location': {'address': '357 Hayes St',
#     'crossStreet': 'at Franklin St',
#     'lat': 37.7768639,
#     'lng': -122.421964,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.7768639,
#       'lng': -122.421964}],
#     'distance': 268,
#     'postalCode': '94102',
#     'cc': 'US',
#     'neighborhood': 'Civic Center',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['357 Hayes St (at Franklin St)',
#      'San Francisco, CA 94102',
#      'United States']},
#    'categories': [{'id': '4d954afda243a5684865b473',
#      'name': 'Optical Shop',
#      'pluralName': 'Optical Shops',
#      'shortName': 'Optical',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_opticalshop_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-5473635d498e14e5b792756d-15'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '57b3c7c8498e9b9e08349941',
#    'name': 'Linden Room',
#    'location': {'address': '330 Gough St',
#     'crossStreet': 'at Linden St',
#     'lat': 37.77650338991626,
#     'lng': -122.42279392034109,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.77650338991626,
#       'lng': -122.42279392034109}],
#     'distance': 308,
#     'postalCode': '94102',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['330 Gough St (at Linden St)',
#      'San Francisco, CA 94102',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d11e941735',
#      'name': 'Cocktail Bar',
#      'pluralName': 'Cocktail Bars',
#      'shortName': 'Cocktail',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-57b3c7c8498e9b9e08349941-16'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4a45ae19f964a52073a81fe3',
#    'name': 'Otoro Sushi',
#    'location': {'address': '205 Oak St',
#     'lat': 37.77497378603595,
#     'lng': -122.42290047871022,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.77497378603595,
#       'lng': -122.42290047871022}],
#     'distance': 290,
#     'postalCode': '94102',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['205 Oak St',
#      'San Francisco, CA 94102',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1d2941735',
#      'name': 'Sushi Restaurant',
#      'pluralName': 'Sushi Restaurants',
#      'shortName': 'Sushi',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4a45ae19f964a52073a81fe3-17'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '52509016498efba365a2f4de',
#    'name': 'Maker & Moss',
#    'location': {'address': '364 Hayes St',
#     'lat': 37.77714415477228,
#     'lng': -122.42236797826467,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.77714415477228,
#       'lng': -122.42236797826467}],
#     'distance': 315,
#     'postalCode': '94102',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['364 Hayes St',
#      'San Francisco, CA 94102',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1f8941735',
#      'name': 'Furniture / Home Store',
#      'pluralName': 'Furniture / Home Stores',
#      'shortName': 'Furniture / Home',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-52509016498efba365a2f4de-18'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '435d7580f964a5201a291fe3',
#    'name': 'Zuni Café',
#    'location': {'address': '1658 Market St',
#     'crossStreet': 'at Rose St',
#     'lat': 37.773589712511665,
#     'lng': -122.42151999253659,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.773589712511665,
#       'lng': -122.42151999253659}],
#     'distance': 254,
#     'postalCode': '94102',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['1658 Market St (at Rose St)',
#      'San Francisco, CA 94102',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d157941735',
#      'name': 'New American Restaurant',
#      'pluralName': 'New American Restaurants',
#      'shortName': 'New American',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-435d7580f964a5201a291fe3-19'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4d9bc0387ae55481046d3f74',
#    'name': 'Linden Alley',
#    'location': {'address': 'Linden St',
#     'crossStreet': 'btwn Octavia & Gough St',
#     'lat': 37.77632881728594,
#     'lng': -122.42359399795532,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.77632881728594,
#       'lng': -122.42359399795532}],
#     'distance': 366,
#     'postalCode': '94102',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['Linden St (btwn Octavia & Gough St)',
#      'San Francisco, CA 94102',
#      'United States']},
#    'categories': [{'id': '52e81612bcbc57f1066b7a25',
#      'name': 'Pedestrian Plaza',
#      'pluralName': 'Pedestrian Plazas',
#      'shortName': 'Pedestrian Street/Plaza',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/default_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4d9bc0387ae55481046d3f74-20'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '49c7dcc3f964a520c9571fe3',
#    'name': 'War Memorial Opera House',
#    'location': {'address': '301 Van Ness Ave',
#     'crossStreet': 'at Grove St',
#     'lat': 37.77860106097681,
#     'lng': -122.42081554583409,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.77860106097681,
#       'lng': -122.42081554583409}],
#     'distance': 380,
#     'postalCode': '94102',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['301 Van Ness Ave (at Grove St)',
#      'San Francisco, CA 94102',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d136941735',
#      'name': 'Opera House',
#      'pluralName': 'Opera Houses',
#      'shortName': 'Opera House',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_operahouse_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-49c7dcc3f964a520c9571fe3-21'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '44d43fb3f964a5204d361fe3',
#    'name': 'Suginami Aikikai',
#    'location': {'address': '141 11th St',
#     'crossStreet': 'Minna',
#     'lat': 37.77401839646871,
#     'lng': -122.41647594124373,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.77401839646871,
#       'lng': -122.41647594124373}],
#     'distance': 312,
#     'postalCode': '94103',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['141 11th St (Minna)',
#      'San Francisco, CA 94103',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d101941735',
#      'name': 'Martial Arts Dojo',
#      'pluralName': 'Martial Arts Dojos',
#      'shortName': 'Martial Arts',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_martialarts_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-44d43fb3f964a5204d361fe3-22'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4b2e994af964a5205ee324e3',
#    'name': 'San Francisco Ballet',
#    'location': {'address': '455 Franklin St',
#     'crossStreet': 'btw Fulton & Grove',
#     'lat': 37.77858023622605,
#     'lng': -122.42079814446592,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.77858023622605,
#       'lng': -122.42079814446592}],
#     'distance': 377,
#     'postalCode': '94102',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['455 Franklin St (btw Fulton & Grove)',
#      'San Francisco, CA 94102',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d134941735',
#      'name': 'Dance Studio',
#      'pluralName': 'Dance Studios',
#      'shortName': 'Dance Studio',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_dancestudio_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4b2e994af964a5205ee324e3-23'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '51aad1ee498e9bb839540dc7',
#    'name': 'Fig & Thistle Wine Bar',
#    'location': {'address': '313 Ivy St',
#     'crossStreet': 'Gough',
#     'lat': 37.777256,
#     'lng': -122.423365,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.777256,
#       'lng': -122.423365}],
#     'distance': 393,
#     'postalCode': '94102',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['313 Ivy St (Gough)',
#      'San Francisco, CA 94102',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d123941735',
#      'name': 'Wine Bar',
#      'pluralName': 'Wine Bars',
#      'shortName': 'Wine Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-51aad1ee498e9bb839540dc7-24'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4aa9afacf964a520e05420e3',
#    'name': 'Arlequin Wine Merchant',
#    'location': {'address': '384 Hayes St',
#     'crossStreet': 'at Gough St',
#     'lat': 37.77706078179804,
#     'lng': -122.4226046384463,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.77706078179804,
#       'lng': -122.4226046384463}],
#     'distance': 326,
#     'postalCode': '94102',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['384 Hayes St (at Gough St)',
#      'San Francisco, CA 94102',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d119951735',
#      'name': 'Wine Shop',
#      'pluralName': 'Wine Shops',
#      'shortName': 'Wine Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_wineshop_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4aa9afacf964a520e05420e3-25'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4cca43b1e47f54817ef7c6f7',
#    'name': 'Welcome Stranger',
#    'location': {'address': '460 Gough St',
#     'lat': 37.777498514169416,
#     'lng': -122.4231245664023,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.777498514169416,
#       'lng': -122.4231245664023}],
#     'distance': 392,
#     'postalCode': '94102',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['460 Gough St',
#      'San Francisco, CA 94102',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d106951735',
#      'name': "Men's Store",
#      'pluralName': "Men's Stores",
#      'shortName': "Men's Store",
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_men_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '427826063'}},
#   'referralId': 'e-0-4cca43b1e47f54817ef7c6f7-26'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4dd94350e4cd37c893d8146f',
#    'name': 'Ritual Coffee Roasters',
#    'location': {'address': '432B Octavia St',
#     'crossStreet': 'at Hayes St',
#     'lat': 37.776476344721765,
#     'lng': -122.42428110362547,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.776476344721765,
#       'lng': -122.42428110362547}],
#     'distance': 429,
#     'postalCode': '94102',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['432B Octavia St (at Hayes St)',
#      'San Francisco, CA 94102',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1e0931735',
#      'name': 'Coffee Shop',
#      'pluralName': 'Coffee Shops',
#      'shortName': 'Coffee Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '52354550'}},
#   'referralId': 'e-0-4dd94350e4cd37c893d8146f-27'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '56b01f27498e2d7609bb9589',
#    'name': 'Urban Pharm',
#    'location': {'address': '122 10th St',
#     'crossStreet': 'Mission St.',
#     'lat': 37.77494954387625,
#     'lng': -122.41560297485357,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.77494954387625,
#       'lng': -122.41560297485357}],
#     'distance': 356,
#     'postalCode': '94103',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['122 10th St (Mission St.)',
#      'San Francisco, CA 94103',
#      'United States']},
#    'categories': [{'id': '52c71aaf3cf9994f4e043d17',
#      'name': 'Marijuana Dispensary',
#      'pluralName': 'Marijuana Dispensaries',
#      'shortName': 'Dispensary',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/dispensary_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-56b01f27498e2d7609bb9589-28'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4d964291daec224b08b9123e',
#    'name': 'Smitten Ice Cream',
#    'location': {'address': '432 Octavia St #1A',
#     'crossStreet': 'at Linden St',
#     'lat': 37.77627287864489,
#     'lng': -122.4242347862329,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.77627287864489,
#       'lng': -122.4242347862329}],
#     'distance': 419,
#     'postalCode': '94102',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['432 Octavia St #1A (at Linden St)',
#      'San Francisco, CA 94102',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1c9941735',
#      'name': 'Ice Cream Shop',
#      'pluralName': 'Ice Cream Shops',
#      'shortName': 'Ice Cream',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '52310139'}},
#   'referralId': 'e-0-4d964291daec224b08b9123e-29'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '42c48780f964a520ce251fe3',
#    'name': 'Isotope Comics',
#    'location': {'address': '326 Fell St',
#     'crossStreet': 'btwn Gough & Octavia St',
#     'lat': 37.775993995578204,
#     'lng': -122.42329274746461,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.775993995578204,
#       'lng': -122.42329274746461}],
#     'distance': 331,
#     'postalCode': '94102',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['326 Fell St (btwn Gough & Octavia St)',
#      'San Francisco, CA 94102',
#      'United States']},
#    'categories': [{'id': '52f2ab2ebcbc57f1066b8b18',
#      'name': 'Comic Shop',
#      'pluralName': 'Comic Shops',
#      'shortName': 'Comic Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/comic_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-42c48780f964a520ce251fe3-30'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '43dc103ef964a520992e1fe3',
#    'name': 'Absinthe Brasserie & Bar',
#    'location': {'address': '398 Hayes St',
#     'crossStreet': 'at Gough St',
#     'lat': 37.7770088434818,
#     'lng': -122.423003716262,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.7770088434818,
#       'lng': -122.423003716262}],
#     'distance': 351,
#     'postalCode': '94102',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['398 Hayes St (at Gough St)',
#      'San Francisco, CA 94102',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d10c941735',
#      'name': 'French Restaurant',
#      'pluralName': 'French Restaurants',
#      'shortName': 'French',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-43dc103ef964a520992e1fe3-31'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '574254c7498e1eb5e05a9d57',
#    'name': 'Boba Guys',
#    'location': {'address': '8 Octavia St Unit 308',
#     'crossStreet': 'at Haight St',
#     'lat': 37.77290679880422,
#     'lng': -122.42350730562886,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.77290679880422,
#       'lng': -122.42350730562886}],
#     'distance': 434,
#     'postalCode': '94102',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['8 Octavia St Unit 308 (at Haight St)',
#      'San Francisco, CA 94102',
#      'United States']},
#    'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#      'name': 'Bubble Tea Shop',
#      'pluralName': 'Bubble Tea Shops',
#      'shortName': 'Bubble Tea',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '219358648'}},
#   'referralId': 'e-0-574254c7498e1eb5e05a9d57-32'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4b54df8ff964a520c7d027e3',
#    'name': "Ted's Market & Deli",
#    'location': {'address': '1530 Howard St',
#     'crossStreet': 'at 11th St',
#     'lat': 37.77286635667847,
#     'lng': -122.41621389845177,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.77286635667847,
#       'lng': -122.41621389845177}],
#     'distance': 405,
#     'postalCode': '94103',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['1530 Howard St (at 11th St)',
#      'San Francisco, CA 94103',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d146941735',
#      'name': 'Deli / Bodega',
#      'pluralName': 'Delis / Bodegas',
#      'shortName': 'Deli / Bodega',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '549106',
#     'url': 'https://www.grubhub.com/restaurant/teds-market--deli-1530-howard-st-san-francisco/549106?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=549106',
#     'provider': {'name': 'grubhub',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_grubhub_20180129.png'}}},
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '136984457'}},
#   'referralId': 'e-0-4b54df8ff964a520c7d027e3-33'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '53b4dd52498eef48c82d89a5',
#    'name': 'Monsieur Benjamin',
#    'location': {'address': '451 Gough St',
#     'lat': 37.77747803178731,
#     'lng': -122.42313085901189,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.77747803178731,
#       'lng': -122.42313085901189}],
#     'distance': 391,
#     'postalCode': '94102',
#     'cc': 'US',
#     'neighborhood': 'Hayes Valley',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['451 Gough St',
#      'San Francisco, CA 94102',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d10c941735',
#      'name': 'French Restaurant',
#      'pluralName': 'French Restaurants',
#      'shortName': 'French',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '93664723'}},
#   'referralId': 'e-0-53b4dd52498eef48c82d89a5-34'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '49d3e017f964a5201e5c1fe3',
#    'name': 'Jardinière',
#    'location': {'address': '300 Grove St',
#     'crossStreet': 'at Franklin St',
#     'lat': 37.778042041793185,
#     'lng': -122.42172473936934,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.778042041793185,
#       'lng': -122.42172473936934}],
#     'distance': 355,
#     'postalCode': '94102',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['300 Grove St (at Franklin St)',
#      'San Francisco, CA 94102',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d10c941735',
#      'name': 'French Restaurant',
#      'pluralName': 'French Restaurants',
#      'shortName': 'French',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '36716132'}},
#   'referralId': 'e-0-49d3e017f964a5201e5c1fe3-35'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4dd7e48fd22d38ef42f35bd8',
#    'name': 'Biergarten',
#    'location': {'address': '424 Octavia St',
#     'crossStreet': 'btwn Linden & Fell St',
#     'lat': 37.77601325805514,
#     'lng': -122.42424739149521,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.77601325805514,
#       'lng': -122.42424739149521}],
#     'distance': 413,
#     'postalCode': '94102',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['424 Octavia St (btwn Linden & Fell St)',
#      'San Francisco, CA 94102',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d117941735',
#      'name': 'Beer Garden',
#      'pluralName': 'Beer Gardens',
#      'shortName': 'Beer Garden',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/beergarden_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '33219322'}},
#   'referralId': 'e-0-4dd7e48fd22d38ef42f35bd8-36'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '5907aa1c178a2a76066e0f59',
#    'name': 'a Mano',
#    'location': {'address': '450 Hayes St',
#     'crossStreet': 'Octavia Street',
#     'lat': 37.776916945347146,
#     'lng': -122.42385625239876,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.776916945347146,
#       'lng': -122.42385625239876}],
#     'distance': 412,
#     'postalCode': '94102',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['450 Hayes St (Octavia Street)',
#      'San Francisco, CA 94102',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d110941735',
#      'name': 'Italian Restaurant',
#      'pluralName': 'Italian Restaurants',
#      'shortName': 'Italian',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '1358641493'}},
#   'referralId': 'e-0-5907aa1c178a2a76066e0f59-37'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '58c235d16ad5a1406910da40',
#    'name': 'Anina',
#    'location': {'address': '482 Hayes St',
#     'crossStreet': 'Octavia Street',
#     'lat': 37.77671255766366,
#     'lng': -122.42427346398327,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.77671255766366,
#       'lng': -122.42427346398327}],
#     'distance': 437,
#     'postalCode': '94102',
#     'cc': 'US',
#     'neighborhood': 'Hayes Valley',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['482 Hayes St (Octavia Street)',
#      'San Francisco, CA 94102',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d11e941735',
#      'name': 'Cocktail Bar',
#      'pluralName': 'Cocktail Bars',
#      'shortName': 'Cocktail',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-58c235d16ad5a1406910da40-38'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '551b7760498e1612b67f33f9',
#    'name': 'Birba',
#    'location': {'address': '458 Grove St',
#     'crossStreet': 'btwn Gough & Octavia St',
#     'lat': 37.77774961586494,
#     'lng': -122.42415851391236,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.77774961586494,
#       'lng': -122.42415851391236}],
#     'distance': 482,
#     'postalCode': '94102',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['458 Grove St (btwn Gough & Octavia St)',
#      'San Francisco, CA 94102',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d123941735',
#      'name': 'Wine Bar',
#      'pluralName': 'Wine Bars',
#      'shortName': 'Wine Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-551b7760498e1612b67f33f9-39'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '49da61f2f964a520815e1fe3',
#    'name': 'Chantal Guillon Macarons & Tea',
#    'location': {'address': '437 Hayes St',
#     'crossStreet': 'at Gough St',
#     'lat': 37.776788858914664,
#     'lng': -122.42360597285621,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.776788858914664,
#       'lng': -122.42360597285621}],
#     'distance': 386,
#     'postalCode': '94102',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['437 Hayes St (at Gough St)',
#      'San Francisco, CA 94102',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1d0941735',
#      'name': 'Dessert Shop',
#      'pluralName': 'Dessert Shops',
#      'shortName': 'Desserts',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#       'suffix': '.png'},
#      'primary': True}],
#    'delivery': {'id': '550794',
#     'url': 'https://www.grubhub.com/restaurant/chantal-guillon-macarons-437-hayes-st-san-francisco/550794?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=550794',
#     'provider': {'name': 'grubhub',
#      'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#       'sizes': [40, 50],
#       'name': '/delivery_provider_grubhub_20180129.png'}}},
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-49da61f2f964a520815e1fe3-40'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '5622d1d7498eec470c196e3a',
#    'name': 'Herbst Theater',
#    'location': {'address': '401 Van Ness Ave',
#     'crossStreet': 'at McAllister St',
#     'lat': 37.779548182877924,
#     'lng': -122.42095293686124,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.779548182877924,
#       'lng': -122.42095293686124}],
#     'distance': 485,
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['401 Van Ness Ave (at McAllister St)',
#      'San Francisco, CA',
#      'United States']},
#    'categories': [{'id': '5032792091d4c4b30a586d5c',
#      'name': 'Concert Hall',
#      'pluralName': 'Concert Halls',
#      'shortName': 'Concert Hall',
# ...
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '53255588'}},
#   'referralId': 'e-0-4a73812ff964a520a0dc1fe3-85'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4b155230f964a520e5aa23e3',
#    'name': 'Asta Yoga',
#    'location': {'address': '417 14th St',
#     'crossStreet': 'Valencia St.',
#     'lat': 37.768070092961636,
#     'lng': -122.42259099222349,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.768070092961636,
#       'lng': -122.42259099222349}],
#     'distance': 847,
#     'postalCode': '94103',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['417 14th St (Valencia St.)',
#      'San Francisco, CA 94103',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d102941735',
#      'name': 'Yoga Studio',
#      'pluralName': 'Yoga Studios',
#      'shortName': 'Yoga Studio',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '66962274'}},
#   'referralId': 'e-0-4b155230f964a520e5aa23e3-86'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4ac697f8f964a52052b520e3',
#    'name': 'SF Moto',
#    'location': {'address': '275 8th St',
#     'crossStreet': 'Folsom',
#     'lat': 37.77530592995251,
#     'lng': -122.410382542049,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.77530592995251,
#       'lng': -122.410382542049}],
#     'distance': 813,
#     'postalCode': '94103',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['275 8th St (Folsom)',
#      'San Francisco, CA 94103',
#      'United States']},
#    'categories': [{'id': '5032833091d4c4b30a586d60',
#      'name': 'Motorcycle Shop',
#      'pluralName': 'Motorcycle Shops',
#      'shortName': 'Motorcycle Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/motorcycle_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '38557430'}},
#   'referralId': 'e-0-4ac697f8f964a52052b520e3-87'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '50427be8e4b09c6ce4ee30b4',
#    'name': 'SF Eagle',
#    'location': {'address': '398 12th St',
#     'crossStreet': 'at Harrison St',
#     'lat': 37.76999502965219,
#     'lng': -122.41330528696156,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.76999502965219,
#       'lng': -122.41330528696156}],
#     'distance': 812,
#     'postalCode': '94103',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['398 12th St (at Harrison St)',
#      'San Francisco, CA 94103',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1d8941735',
#      'name': 'Gay Bar',
#      'pluralName': 'Gay Bars',
#      'shortName': 'Gay Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/gaybar_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-50427be8e4b09c6ce4ee30b4-88'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4be75ea92468c9288b750243',
#    'name': 'Glama-Rama Salon',
#    'location': {'address': '304 Valencia St',
#     'crossStreet': 'at 14th St',
#     'lat': 37.76798071725617,
#     'lng': -122.42224110845568,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.76798071725617,
#       'lng': -122.42224110845568}],
#     'distance': 848,
#     'postalCode': '94103',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['304 Valencia St (at 14th St)',
#      'San Francisco, CA 94103',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d110951735',
#      'name': 'Salon / Barbershop',
#      'pluralName': 'Salons / Barbershops',
#      'shortName': 'Salon / Barbershop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4be75ea92468c9288b750243-89'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '49f356f8f964a5208a6a1fe3',
#    'name': "Brenda's French Soul Food",
#    'location': {'address': '652 Polk St',
#     'crossStreet': 'btwn Eddy & Turk St',
#     'lat': 37.782896409128426,
#     'lng': -122.41889744997026,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.782896409128426,
#       'lng': -122.41889744997026}],
#     'distance': 846,
#     'postalCode': '94102',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['652 Polk St (btwn Eddy & Turk St)',
#      'San Francisco, CA 94102',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d14f941735',
#      'name': 'Southern / Soul Food Restaurant',
#      'pluralName': 'Southern / Soul Food Restaurants',
#      'shortName': 'Southern / Soul',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/southern_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-49f356f8f964a5208a6a1fe3-90'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4a3f0ce4f964a520aca31fe3',
#    'name': 'Pet Food Express',
#    'location': {'address': '1975 Market St',
#     'crossStreet': '(Between Duboce & Dolores)',
#     'lat': 37.76923879073783,
#     'lng': -122.42627112387855,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.76923879073783,
#       'lng': -122.42627112387855}],
#     'distance': 894,
#     'postalCode': '94103',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['1975 Market St ((Between Duboce & Dolores))',
#      'San Francisco, CA 94103',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d100951735',
#      'name': 'Pet Store',
#      'pluralName': 'Pet Stores',
#      'shortName': 'Pet Store',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pet_store_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4a3f0ce4f964a520aca31fe3-91'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '5ae925e7c0f163002cc57349',
#    'name': 'Birdsong',
#    'location': {'address': '1085 Mission St',
#     'crossStreet': '7th',
#     'lat': 37.77942453003254,
#     'lng': -122.41047319701762,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.77942453003254,
#       'lng': -122.41047319701762}],
#     'distance': 926,
#     'postalCode': '94103',
#     'cc': 'US',
#     'neighborhood': 'SoMa',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['1085 Mission St (7th)',
#      'San Francisco, CA 94103',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1c4941735',
#      'name': 'Restaurant',
#      'pluralName': 'Restaurants',
#      'shortName': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-5ae925e7c0f163002cc57349-92'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '43eb7d31f964a520392f1fe3',
#    'name': 'Saigon Sandwich',
#    'location': {'address': '560 Larkin St',
#     'crossStreet': 'btwn Eddy & Turk St',
#     'lat': 37.783084082892096,
#     'lng': -122.41764971994778,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.783084082892096,
#       'lng': -122.41764971994778}],
#     'distance': 882,
#     'postalCode': '94102',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['560 Larkin St (btwn Eddy & Turk St)',
#      'San Francisco, CA 94102',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1c5941735',
#      'name': 'Sandwich Place',
#      'pluralName': 'Sandwich Places',
#      'shortName': 'Sandwiches',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '104884418'}},
#   'referralId': 'e-0-43eb7d31f964a520392f1fe3-93'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '43470c00f964a52080281fe3',
#    'name': 'Walzwerk',
#    'location': {'address': '381 S Van Ness Ave',
#     'crossStreet': 'at 15th St',
#     'lat': 37.767209340699445,
#     'lng': -122.41770720693161,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.767209340699445,
#       'lng': -122.41770720693161}],
#     'distance': 918,
#     'postalCode': '94103',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['381 S Van Ness Ave (at 15th St)',
#      'San Francisco, CA 94103',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d10d941735',
#      'name': 'German Restaurant',
#      'pluralName': 'German Restaurants',
#      'shortName': 'German',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/german_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '71425107'}},
#   'referralId': 'e-0-43470c00f964a52080281fe3-94'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '44edbcecf964a520e0371fe3',
#    'name': 'Mr. S Leather & Mr. S Locker Room',
#    'location': {'address': '385 8th St',
#     'crossStreet': 'at Harrison St',
#     'lat': 37.77411705607826,
#     'lng': -122.4088527466002,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.77411705607826,
#       'lng': -122.4088527466002}],
#     'distance': 957,
#     'postalCode': '94103',
#     'cc': 'US',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['385 8th St (at Harrison St)',
#      'San Francisco, CA 94103',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d103951735',
#      'name': 'Clothing Store',
#      'pluralName': 'Clothing Stores',
#      'shortName': 'Apparel',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-44edbcecf964a520e0371fe3-95'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '59b759e1646e387b4245f12a',
#    'name': 'Villon',
#    'location': {'address': '1100 Market St',
#     'lat': 37.780865252229155,
#     'lng': -122.41247055353418,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.780865252229155,
#       'lng': -122.41247055353418}],
#     'distance': 882,
#     'postalCode': '94102',
#     'cc': 'US',
#     'neighborhood': 'Tenderloin',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['1100 Market St',
#      'San Francisco, CA 94102',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d10c941735',
#      'name': 'French Restaurant',
#      'pluralName': 'French Restaurants',
#      'shortName': 'French',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-59b759e1646e387b4245f12a-96'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '480d1a5ef964a520284f1fe3',
#    'name': 'Four Barrel Coffee',
#    'location': {'address': '375 Valencia St',
#     'crossStreet': 'btwn 14th St & 15th St',
#     'lat': 37.767012532041115,
#     'lng': -122.42201032995501,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.767012532041115,
#       'lng': -122.42201032995501}],
#     'distance': 947,
#     'postalCode': '94103',
#     'cc': 'US',
#     'neighborhood': 'Mission District',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['375 Valencia St (btwn 14th St & 15th St)',
#      'San Francisco, CA 94103',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1e0931735',
#      'name': 'Coffee Shop',
#      'pluralName': 'Coffee Shops',
#      'shortName': 'Coffee Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '52311110'}},
#   'referralId': 'e-0-480d1a5ef964a520284f1fe3-97'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '522926b5498e3269edeba28d',
#    'name': 'The Center SF',
#    'location': {'lat': 37.77454451433456,
#     'lng': -122.43073033291728,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.77454451433456,
#       'lng': -122.43073033291728}],
#     'distance': 980,
#     'cc': 'US',
#     'neighborhood': 'Lower Haight',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['San Francisco, CA', 'United States']},
#    'categories': [{'id': '4bf58dd8d48988d131941735',
#      'name': 'Spiritual Center',
#      'pluralName': 'Spiritual Centers',
#      'shortName': 'Spiritual',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/religious_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-522926b5498e3269edeba28d-98'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '57535ff2498e2b523492650e',
#    'name': 'San Francisco Pole and Dance',
#    'location': {'address': '301 8th St #225',
#     'lat': 37.77475980307061,
#     'lng': -122.40966587200884,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.77475980307061,
#       'lng': -122.40966587200884}],
#     'distance': 878,
#     'postalCode': '94103',
#     'cc': 'US',
#     'neighborhood': 'SoMa',
#     'city': 'San Francisco',
#     'state': 'CA',
#     'country': 'United States',
#     'formattedAddress': ['301 8th St #225',
#      'San Francisco, CA 94103',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d134941735',
#      'name': 'Dance Studio',
#      'pluralName': 'Dance Studios',
#      'shortName': 'Dance Studio',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_dancestudio_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-57535ff2498e2b523492650e-99'}]

# %%
# Print selected Venue Name results, to verify the object referencing:
# results['response']['groups'][0]['items'][0]['venue']['name']  --> 'SFJazz Center'
for i in range(20):
    print(results['response']['groups'][0]['items'][i]['venue']['name'])
# Out:
# SFJazz Center
# New Conservatory Theatre Center
# Blue Bottle Coffee
# Nojo Ramen Tavern
# Cala
# Sydney Goldstein Theater
# Louise M. Davies Symphony Hall
# Fatted Calf
# Hotel Biron
# The Beer Hall
# Rich Table
# Fitness SF
# Veer & Wander
# Blue Bottle Coffee
# Siam Orchid Traditional Thai Massage
# Warby Parker
# Linden Room
# Otoro Sushi
# Maker & Moss
# Zuni Café

# %%
# From our Foursquare lab, we know that all the information is in the items key. 
# Define function get_category_type to retrieve the venue's category
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
# Now we clean the JSON object and structure it into a pandas dataframe.
search_query_SF = 'venues'
venues_SF = results['response']['groups'][0]['items']
nearby_venues_SF = json_normalize(venues_SF)     # flatten JSON
nearby_venues_SF.head()
# Out:
#    reasons.count                                      reasons.items  \
# 0              0  [{'summary': 'This spot is popular', 'type': '...
# 1              0  [{'summary': 'This spot is popular', 'type': '...
# 2              0  [{'summary': 'This spot is popular', 'type': '...
# 3              0  [{'summary': 'This spot is popular', 'type': '...
# 4              0  [{'summary': 'This spot is popular', 'type': '...
#
#                        referralId  \
# 0  e-0-50f21340e4b036c5cc0d7c7d-0
# 1  e-0-4a346043f964a520279c1fe3-1
# 2  e-0-5560dbdb498e91a2bcde84f6-2
# 3  e-0-4d8eabc7d265236af9a71017-3
# 4  e-0-5600850a498edff486fdfe89-4
#
#                                     venue.categories venue.delivery.id  \
# 0  [{'id': '4bf58dd8d48988d1e7931735', 'name': 'J...               NaN
# 1  [{'id': '4bf58dd8d48988d137941735', 'name': 'T...               NaN
# 2  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...               NaN
# 3  [{'id': '55a59bace4b013909087cb24', 'name': 'R...               NaN
# 4  [{'id': '4bf58dd8d48988d1c1941735', 'name': 'M...               NaN
#
#   venue.delivery.provider.icon.name venue.delivery.provider.icon.prefix  \
# 0                               NaN                                 NaN
# 1                               NaN                                 NaN
# 2                               NaN                                 NaN
# 3                               NaN                                 NaN
# 4                               NaN                                 NaN
#
#   venue.delivery.provider.icon.sizes venue.delivery.provider.name  \
# 0                                NaN                          NaN
# 1                                NaN                          NaN
# 2                                NaN                          NaN
# 3                                NaN                          NaN
# 4                                NaN                          NaN
#
#   venue.delivery.url                  venue.id  venue.location.address  \
# 0                NaN  50f21340e4b036c5cc0d7c7d         201 Franklin St
# 1                NaN  4a346043f964a520279c1fe3         25 Van Ness Ave
# 2                NaN  5560dbdb498e91a2bcde84f6  1355 Market St Ste 190
# 3                NaN  4d8eabc7d265236af9a71017         231 Franklin St
# 4                NaN  5600850a498edff486fdfe89             149 Fell St
#
#   venue.location.cc venue.location.city venue.location.country  \
# 0                US       San Francisco          United States
# 1                US       San Francisco          United States
# 2                US       San Francisco          United States
# 3                US       San Francisco          United States
# 4                US       San Francisco          United States
#
#    venue.location.crossStreet  venue.location.distance  \
# 0                  at Fell St                      203
# 1                      Oak St                       32
# 2                  at 10th St                      265
# 3                at Linden St                      206
# 4  btwn Franklin and Van Ness                      106
#
#                      venue.location.formattedAddress  \
# 0  [201 Franklin St (at Fell St), San Francisco, ...
# 1  [25 Van Ness Ave (Oak St), San Francisco, CA 9...
# 2  [1355 Market St Ste 190 (at 10th St), San Fran...
# 3  [231 Franklin St (at Linden St), San Francisco...
# 4  [149 Fell St (btwn Franklin and Van Ness), San...
#
#                        venue.location.labeledLatLngs  venue.location.lat  \
# 0  [{'label': 'display', 'lat': 37.77635001768186...           37.776350
# 1  [{'label': 'display', 'lat': 37.77559103972081...           37.775591
# 2  [{'label': 'display', 'lat': 37.77628641647586...           37.776286
# 3  [{'label': 'display', 'lat': 37.77663659663732...           37.776637
# 4  [{'label': 'display', 'lat': 37.77606310699734...           37.776063
#
#    venue.location.lng venue.location.neighborhood venue.location.postalCode  \
# 0         -122.421539                Civic Center                     94102
# 1         -122.419753                         NaN                     94102
# 2         -122.416867                         NaN                     94103
# 3         -122.421270                         NaN                     94102
# 4         -122.420386                         NaN                     94102
#
#   venue.location.state                       venue.name  venue.photos.count  \
# 0                   CA                    SFJazz Center                   0
# 1                   CA  New Conservatory Theatre Center                   0
# 2                   CA               Blue Bottle Coffee                   0
# 3                   CA                Nojo Ramen Tavern                   0
# 4                   CA                             Cala                   0
#
#   venue.photos.groups venue.venuePage.id
# 0                  []                NaN
# 1                  []           75569151
# 2                  []                NaN
# 3                  []                NaN
# 4                  []                NaN

# %%
# Repeat the analysis for Seattle / Pioneer Square area

# Display map of the San Francisco / SOMA (South of Market) Area
map_SeattlePS = folium.Map(location=[latitude_SeattlePS, longitude_SeattlePS], tiles='Stamen Terrain', zoom_start=12)

folium.Marker(location=[latitude_SeattlePS, longitude_SeattlePS], popup='Seattle').add_to(map_SeattlePS)
folium.CircleMarker(location=[latitude_SeattlePS, longitude_SeattlePS], radius=10,
popup='Seattle / Pioneer Square', color='#3186cc', fill_color='#3186cc').add_to(map_SeattlePS)

map_SeattlePS
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Seattle / Pioneer Square area:
# Analyze venues / local businesses within 1500 meters of the target neighborhood (approx. 1 mile radius)
radius = 1500
limit = 100
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, VERSION, latitude_SeattlePS, longitude_SeattlePS, radius, limit)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=0L5LJUZ1ZRIICXKIV3JEBXMSIR2A2WUKTL2PYY2UE22TX5DL&client_secret=OE2B2ZNPTMOQCWJATIXF1IBTKWIMPZT5Q3OO0PE2LBPN0UFI&v=20180605&ll=47.601954,-122.329204&radius=1500&limit=100'

# %%
results = requests.get(url).json()

# results

# Test selected objects and venues from the dataset - focus on the 'items' object
# print("meta: requestId: ", results['meta']['requestId'])
# print("response: suggestedBounds: 'ne', 'sw' \n", results['response']['suggestedBounds']['ne'], '\n', results['response']['suggestedBounds']['sw'])
results['response']['groups'][0]['items']
# Out:
# [{'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4db71ec1a86ed8d46c6e179c',
#    'name': 'Il Corvo',
#    'location': {'address': '217 James St',
#     'crossStreet': 'btwn 2nd & 3rd Ave',
#     'lat': 47.602521877965955,
#     'lng': -122.33195233639914,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.602521877965955,
#       'lng': -122.33195233639914}],
#     'distance': 215,
#     'postalCode': '98104',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['217 James St (btwn 2nd & 3rd Ave)',
#      'Seattle, WA 98104',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d110941735',
#      'name': 'Italian Restaurant',
#      'pluralName': 'Italian Restaurants',
#      'shortName': 'Italian',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4db71ec1a86ed8d46c6e179c-0'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '56b101bb498e4905510a5798',
#    'name': 'Flatstick Pub',
#    'location': {'address': '240 2nd Ave S',
#     'crossStreet': 'Main',
#     'lat': 47.60022,
#     'lng': -122.33131,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.60022,
#       'lng': -122.33131}],
#     'distance': 249,
#     'postalCode': '98104',
#     'cc': 'US',
#     'neighborhood': 'Pioneer Square',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['240 2nd Ave S (Main)',
#      'Seattle, WA 98104',
#      'United States']},
#    'categories': [{'id': '56aa371ce4b08b9a8d57356c',
#      'name': 'Beer Bar',
#      'pluralName': 'Beer Bars',
#      'shortName': 'Beer Bar',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '154127947'}},
#   'referralId': 'e-0-56b101bb498e4905510a5798-1'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '545803de498e7e758ac5605e',
#    'name': 'Elm Coffee Roasters',
#    'location': {'address': '240 2nd Avenue Ext S Ste 103',
#     'lat': 47.600152370806754,
#     'lng': -122.33094380272051,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.600152370806754,
#       'lng': -122.33094380272051}],
#     'distance': 239,
#     'postalCode': '98104',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['240 2nd Avenue Ext S Ste 103',
#      'Seattle, WA 98104',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1e0931735',
#      'name': 'Coffee Shop',
#      'pluralName': 'Coffee Shops',
#      'shortName': 'Coffee Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-545803de498e7e758ac5605e-2'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '5762cc9ccd1085a720b1433e',
#    'name': 'Biscuit B*tch',
#    'location': {'address': '621 3rd Ave',
#     'crossStreet': 'James St & Cherry St',
#     'lat': 47.603237,
#     'lng': -122.33201,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.603237,
#       'lng': -122.33201}],
#     'distance': 254,
#     'postalCode': '98104',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['621 3rd Ave (James St & Cherry St)',
#      'Seattle, WA 98104',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d143941735',
#      'name': 'Breakfast Spot',
#      'pluralName': 'Breakfast Spots',
#      'shortName': 'Breakfast',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-5762cc9ccd1085a720b1433e-3'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '455c500ef964a5206e3d1fe3',
#    'name': "Tat's Delicatessen",
#    'location': {'address': '159 Yesler Way',
#     'crossStreet': 'at 2nd Ave',
#     'lat': 47.601901016106545,
#     'lng': -122.3324232258795,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.601901016106545,
#       'lng': -122.3324232258795}],
#     'distance': 241,
#     'postalCode': '98104',
#     'cc': 'US',
#     'neighborhood': 'Pioneer Square',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['159 Yesler Way (at 2nd Ave)',
#      'Seattle, WA 98104',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1c5941735',
#      'name': 'Sandwich Place',
#      'pluralName': 'Sandwich Places',
#      'shortName': 'Sandwiches',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-455c500ef964a5206e3d1fe3-4'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4a3be500f964a520e2a01fe3',
#    'name': 'Tsukushinbo',
#    'location': {'address': '515 S Main St',
#     'crossStreet': 'btw 5th & 6th Ave S',
#     'lat': 47.59996315315612,
#     'lng': -122.32687778842212,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.59996315315612,
#       'lng': -122.32687778842212}],
#     'distance': 282,
#     'postalCode': '98104',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['515 S Main St (btw 5th & 6th Ave S)',
#      'Seattle, WA 98104',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d111941735',
#      'name': 'Japanese Restaurant',
#      'pluralName': 'Japanese Restaurants',
#      'shortName': 'Japanese',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4a3be500f964a520e2a01fe3-5'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '58ab437613af1c6117f3cba6',
#    'name': 'Cherry Street Public House',
#    'location': {'address': '210 Occidental Ave S',
#     'lat': 47.600450463452574,
#     'lng': -122.33290772884978,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.600450463452574,
#       'lng': -122.33290772884978}],
#     'distance': 324,
#     'postalCode': '98104',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['210 Occidental Ave S',
#      'Seattle, WA 98104',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1e0931735',
#      'name': 'Coffee Shop',
#      'pluralName': 'Coffee Shops',
#      'shortName': 'Coffee Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-58ab437613af1c6117f3cba6-6'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '451c049bf964a520803a1fe3',
#    'name': 'Columbia Tower Club',
#    'location': {'address': '701 5th Ave Fl 75',
#     'lat': 47.60450651693834,
#     'lng': -122.33048379421234,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.60450651693834,
#       'lng': -122.33048379421234}],
#     'distance': 299,
#     'postalCode': '98104',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['701 5th Ave Fl 75',
#      'Seattle, WA 98104',
#      'United States']},
#    'categories': [{'id': '52e81612bcbc57f1066b7a33',
#      'name': 'Social Club',
#      'pluralName': 'Social Clubs',
#      'shortName': 'Social Club',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-451c049bf964a520803a1fe3-7'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4a02b07bf964a52069711fe3',
#    'name': 'Smith Tower',
#    'location': {'address': '506 2nd Ave',
#     'crossStreet': 'at Yesler Way',
#     'lat': 47.601857911501355,
#     'lng': -122.33215205034296,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.601857911501355,
#       'lng': -122.33215205034296}],
#     'distance': 221,
#     'postalCode': '98104',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['506 2nd Ave (at Yesler Way)',
#      'Seattle, WA 98104',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d130941735',
#      'name': 'Building',
#      'pluralName': 'Buildings',
#      'shortName': 'Building',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '38681161'}},
#   'referralId': 'e-0-4a02b07bf964a52069711fe3-8'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '5278125a498eb400461d0557',
#    'name': 'Juicy Cafe',
#    'location': {'address': '701 5th Ave',
#     'lat': 47.60432935466306,
#     'lng': -122.33095816698338,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.60432935466306,
#       'lng': -122.33095816698338}],
#     'distance': 295,
#     'postalCode': '98104',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['701 5th Ave', 'Seattle, WA 98104', 'United States']},
#    'categories': [{'id': '4bf58dd8d48988d16d941735',
#      'name': 'Café',
#      'pluralName': 'Cafés',
#      'shortName': 'Café',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-5278125a498eb400461d0557-9'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '546d5049498e6c78df746146',
#    'name': 'Good Bar',
#    'location': {'address': '240 2nd Ave S Ste 101',
#     'crossStreet': 'Main St',
#     'lat': 47.60011606018805,
#     'lng': -122.3315971380008,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.60011606018805,
#       'lng': -122.3315971380008}],
#     'distance': 272,
#     'postalCode': '98104',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['240 2nd Ave S Ste 101 (Main St)',
#      'Seattle, WA 98104',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d11e941735',
#      'name': 'Cocktail Bar',
#      'pluralName': 'Cocktail Bars',
#      'shortName': 'Cocktail',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-546d5049498e6c78df746146-10'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4f4a9c22e4b0b1e352177bc2',
#    'name': 'Smith Tower Observation Deck',
#    'location': {'address': 'Smith Tower',
#     'lat': 47.60187700905275,
#     'lng': -122.33186550011222,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.60187700905275,
#       'lng': -122.33186550011222}],
#     'distance': 199,
#     'postalCode': '98104',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['Smith Tower', 'Seattle, WA 98104', 'United States']},
#    'categories': [{'id': '4bf58dd8d48988d165941735',
#      'name': 'Scenic Lookout',
#      'pluralName': 'Scenic Lookouts',
#      'shortName': 'Scenic Lookout',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sceniclookout_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4f4a9c22e4b0b1e352177bc2-11'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '534d8b3c498e9cf5c6823cd8',
#    'name': 'Damn the Weather',
#    'location': {'address': '116 1st Ave S',
#     'crossStreet': 'Washington',
#     'lat': 47.601004162802,
#     'lng': -122.334119031303,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.601004162802,
#       'lng': -122.334119031303}],
#     'distance': 383,
#     'postalCode': '98104',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['116 1st Ave S (Washington)',
#      'Seattle, WA 98104',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d11e941735',
#      'name': 'Cocktail Bar',
#      'pluralName': 'Cocktail Bars',
#      'shortName': 'Cocktail',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-534d8b3c498e9cf5c6823cd8-12'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '551366a2498e757161a41151',
#    'name': 'The Bar Shoppe',
#    'location': {'address': '117 Yesler',
#     'lat': 47.601737052225594,
#     'lng': -122.33312973915179,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.601737052225594,
#       'lng': -122.33312973915179}],
#     'distance': 295,
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['117 Yesler', 'Seattle, WA', 'United States']},
#    'categories': [{'id': '4bf58dd8d48988d11e941735',
#      'name': 'Cocktail Bar',
#      'pluralName': 'Cocktail Bars',
#      'shortName': 'Cocktail',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-551366a2498e757161a41151-13'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4b82dfb9f964a52042ea30e3',
#    'name': 'Delicatus',
#    'location': {'address': '103 1st Ave S',
#     'crossStreet': 'at Yesler Way',
#     'lat': 47.60157874689764,
#     'lng': -122.33425268668033,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.60157874689764,
#       'lng': -122.33425268668033}],
#     'distance': 381,
#     'postalCode': '98104',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['103 1st Ave S (at Yesler Way)',
#      'Seattle, WA 98104',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d146941735',
#      'name': 'Deli / Bodega',
#      'pluralName': 'Delis / Bodegas',
#      'shortName': 'Deli / Bodega',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '44224832'}},
#   'referralId': 'e-0-4b82dfb9f964a52042ea30e3-14'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '42055e00f964a5206b1f1fe3',
#    'name': 'Maneki',
#    'location': {'address': '304 6th Ave S',
#     'crossStreet': 'btwn Main & Jackson St',
#     'lat': 47.599674852845304,
#     'lng': -122.32636588867386,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.599674852845304,
#       'lng': -122.32636588867386}],
#     'distance': 331,
#     'postalCode': '98104',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['304 6th Ave S (btwn Main & Jackson St)',
#      'Seattle, WA 98104',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1d2941735',
#      'name': 'Sushi Restaurant',
#      'pluralName': 'Sushi Restaurants',
#      'shortName': 'Sushi',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-42055e00f964a5206b1f1fe3-15'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '50173e11e4b0e3bcfbf73e1a',
#    'name': 'Top Pot Doughnuts',
#    'location': {'address': '720 3rd Ave',
#     'crossStreet': 'at Columbia',
#     'lat': 47.60402274781788,
#     'lng': -122.33249924364945,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.60402274781788,
#       'lng': -122.33249924364945}],
#     'distance': 337,
#     'postalCode': '98104',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['720 3rd Ave (at Columbia)',
#      'Seattle, WA 98104',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d148941735',
#      'name': 'Donut Shop',
#      'pluralName': 'Donut Shops',
#      'shortName': 'Donuts',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-50173e11e4b0e3bcfbf73e1a-16'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '5bfda35f894eac002c8f3247',
#    'name': 'Salumi',
#    'location': {'address': '404 Occidental Ave S',
#     'crossStreet': 'Jackson',
#     'lat': 47.599052219606946,
#     'lng': -122.33282245609861,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.599052219606946,
#       'lng': -122.33282245609861}],
#     'distance': 422,
#     'postalCode': '98104',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['404 Occidental Ave S (Jackson)',
#      'Seattle, WA 98104',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d110941735',
#      'name': 'Italian Restaurant',
#      'pluralName': 'Italian Restaurants',
#      'shortName': 'Italian',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-5bfda35f894eac002c8f3247-17'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '49fe4977f964a5208b6f1fe3',
#    'name': 'Caffè Umbria',
#    'location': {'address': '320 Occidental Ave S',
#     'crossStreet': 'btwn Jackson & Main St',
#     'lat': 47.59943514119855,
#     'lng': -122.33285708962083,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.59943514119855,
#       'lng': -122.33285708962083}],
#     'distance': 392,
#     'postalCode': '98104',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['320 Occidental Ave S (btwn Jackson & Main St)',
#      'Seattle, WA 98104',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1e0931735',
#      'name': 'Coffee Shop',
#      'pluralName': 'Coffee Shops',
#      'shortName': 'Coffee Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-49fe4977f964a5208b6f1fe3-18'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '41f6dd80f964a5202b1f1fe3',
#    'name': 'Zeitgeist Kunst & Kaffee',
#    'location': {'address': '171 S Jackson St',
#     'crossStreet': 'at 2nd Ave Ext S',
#     'lat': 47.599122135315895,
#     'lng': -122.33177941627368,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.599122135315895,
#       'lng': -122.33177941627368}],
#     'distance': 369,
#     'postalCode': '98104',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['171 S Jackson St (at 2nd Ave Ext S)',
#      'Seattle, WA 98104',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1e0931735',
#      'name': 'Coffee Shop',
#      'pluralName': 'Coffee Shops',
#      'shortName': 'Coffee Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-41f6dd80f964a5202b1f1fe3-19'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '44f5c6d1f964a5203c381fe3',
#    'name': 'Intrigue Chocolates',
#    'location': {'address': '559 NE 80th St',
#     'crossStreet': 'at 8th',
#     'lat': 47.59918708025387,
#     'lng': -122.33256699519845,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.59918708025387,
#       'lng': -122.33256699519845}],
#     'distance': 398,
#     'postalCode': '98115',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['559 NE 80th St (at 8th)',
#      'Seattle, WA 98115',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d117951735',
#      'name': 'Candy Store',
#      'pluralName': 'Candy Stores',
#      'shortName': 'Candy Store',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/candystore_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-44f5c6d1f964a5203c381fe3-20'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '54b81b49498e6fff726e8027',
#    'name': 'Casco Antiguo',
#    'location': {'address': '115 Occidental Ave S',
#     'crossStreet': 'btwn Yesler & Washington',
#     'lat': 47.60116537635897,
#     'lng': -122.33301339810762,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.60116537635897,
#       'lng': -122.33301339810762}],
#     'distance': 299,
#     'postalCode': '98104',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['115 Occidental Ave S (btwn Yesler & Washington)',
#      'Seattle, WA 98104',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1c1941735',
#      'name': 'Mexican Restaurant',
#      'pluralName': 'Mexican Restaurants',
#      'shortName': 'Mexican',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-54b81b49498e6fff726e8027-21'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '518474ea498e622f11c0c65b',
#    'name': 'Cafe Nordo',
#    'location': {'address': '109 S Main St',
#     'lat': 47.600064713932795,
#     'lng': -122.33362390719242,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.600064713932795,
#       'lng': -122.33362390719242}],
#     'distance': 392,
#     'postalCode': '98104',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['109 S Main St',
#      'Seattle, WA 98104',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d135941735',
#      'name': 'Indie Theater',
#      'pluralName': 'Indie Theaters',
#      'shortName': 'Indie',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-518474ea498e622f11c0c65b-22'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '47b5b90bf964a520ae4d1fe3',
#    'name': 'Metropolitan Grill',
#    'location': {'address': '820 2nd Ave',
#     'crossStreet': 'at Marion St',
#     'lat': 47.60461710688105,
#     'lng': -122.33427985479376,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.60461710688105,
#       'lng': -122.33427985479376}],
#     'distance': 482,
#     'postalCode': '98104',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['820 2nd Ave (at Marion St)',
#      'Seattle, WA 98104',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1cc941735',
#      'name': 'Steakhouse',
#      'pluralName': 'Steakhouses',
#      'shortName': 'Steakhouse',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-47b5b90bf964a520ae4d1fe3-23'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '47efbb37f964a5206f4e1fe3',
#    'name': 'Kinokuniya Book Store',
#    'location': {'address': '525 S Weller St',
#     'crossStreet': 'at 6th Ave S',
#     'lat': 47.59730729413182,
#     'lng': -122.32677280990137,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.59730729413182,
#       'lng': -122.32677280990137}],
#     'distance': 548,
#     'postalCode': '98104',
#     'cc': 'US',
#     'neighborhood': 'International District',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['525 S Weller St (at 6th Ave S)',
#      'Seattle, WA 98104',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d114951735',
#      'name': 'Bookstore',
#      'pluralName': 'Bookstores',
#      'shortName': 'Bookstore',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-47efbb37f964a5206f4e1fe3-24'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4ad50283f964a5203f0121e3',
#    'name': 'Columbia Center Observation Deck (Sky View Observatory)',
#    'location': {'address': '701 5th Ave',
#     'crossStreet': '73rd Floor',
#     'lat': 47.60459497412494,
#     'lng': -122.33081640007372,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.60459497412494,
#       'lng': -122.33081640007372}],
#     'distance': 317,
#     'postalCode': '98104',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['701 5th Ave (73rd Floor)',
#      'Seattle, WA 98104',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d165941735',
#      'name': 'Scenic Lookout',
#      'pluralName': 'Scenic Lookouts',
#      'shortName': 'Scenic Lookout',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sceniclookout_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4ad50283f964a5203f0121e3-25'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4ab7e782f964a5206b7b20e3',
#    'name': 'Red Bowls',
#    'location': {'address': '812 3rd Ave',
#     'crossStreet': 'btw Columbia & Marion',
#     'lat': 47.604654474206626,
#     'lng': -122.3332111438203,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.604654474206626,
#       'lng': -122.3332111438203}],
#     'distance': 425,
#     'postalCode': '98104',
#     'cc': 'US',
#     'neighborhood': 'Seattle Central Business District',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['812 3rd Ave (btw Columbia & Marion)',
#      'Seattle, WA 98104',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1d1941735',
#      'name': 'Noodle House',
#      'pluralName': 'Noodle Houses',
#      'shortName': 'Noodles',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4ab7e782f964a5206b7b20e3-26'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '536d319f498e4c7368d1c831',
#    'name': 'The London Plane',
#    'location': {'address': '300 Occidental Ave S',
#     'crossStreet': 'S Main St',
#     'lat': 47.60004034945503,
#     'lng': -122.3328034077415,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.60004034945503,
#       'lng': -122.3328034077415}],
#     'distance': 344,
#     'postalCode': '98104',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['300 Occidental Ave S (S Main St)',
#      'Seattle, WA 98104',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d16d941735',
#      'name': 'Café',
#      'pluralName': 'Cafés',
#      'shortName': 'Café',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-536d319f498e4c7368d1c831-27'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4aa1b52af964a5207d4120e3',
#    'name': 'KOBO',
#    'location': {'address': '604 S Jackson St',
#     'crossStreet': 'at 6th Ave S',
#     'lat': 47.59920145030391,
#     'lng': -122.3260832149394,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.59920145030391,
#       'lng': -122.3260832149394}],
#     'distance': 385,
#     'postalCode': '98104',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['604 S Jackson St (at 6th Ave S)',
#      'Seattle, WA 98104',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1e2931735',
#      'name': 'Art Gallery',
#      'pluralName': 'Art Galleries',
#      'shortName': 'Art Gallery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4aa1b52af964a5207d4120e3-28'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4f8f5124003960ba6c1c389b',
#    'name': 'Pioneer Pet Feed & Supply',
#    'location': {'address': '87 1/2 S Washington St',
#     'crossStreet': 'btwn 1st Ave S & Alaskan Way S',
#     'lat': 47.60088373457282,
#     'lng': -122.33488107891347,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.60088373457282,
#       'lng': -122.33488107891347}],
#     'distance': 442,
#     'postalCode': '98104',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['87 1/2 S Washington St (btwn 1st Ave S & Alaskan Way S)',
#      'Seattle, WA 98104',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d100951735',
#      'name': 'Pet Store',
#      'pluralName': 'Pet Stores',
#      'shortName': 'Pet Store',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pet_store_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '38467613'}},
#   'referralId': 'e-0-4f8f5124003960ba6c1c389b-29'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '44c14900f964a520b8351fe3',
#    'name': 'Uwajimaya',
#    'location': {'address': '600 5th Ave S',
#     'crossStreet': 'at S Dearborn St',
#     'lat': 47.59710890454062,
#     'lng': -122.3271035216279,
#     'distance': 561,
#     'postalCode': '98104',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['600 5th Ave S (at S Dearborn St)',
#      'Seattle, WA 98104',
#      'United States']},
#    'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#      'name': 'Supermarket',
#      'pluralName': 'Supermarkets',
#      'shortName': 'Supermarket',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-44c14900f964a520b8351fe3-30'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '52818f6511d2686bf631590b',
#    'name': 'Altstadt',
#    'location': {'address': '209 1st Ave S',
#     'crossStreet': 'btwn S Main & S Washington St',
#     'lat': 47.60047592162763,
#     'lng': -122.33431317191629,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.60047592162763,
#       'lng': -122.33431317191629}],
#     'distance': 417,
#     'postalCode': '98104',
#     'cc': 'US',
#     'neighborhood': 'Pioneer Square',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['209 1st Ave S (btwn S Main & S Washington St)',
#      'Seattle, WA 98104',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d10d941735',
#      'name': 'German Restaurant',
#      'pluralName': 'German Restaurants',
#      'shortName': 'German',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/german_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-52818f6511d2686bf631590b-31'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '53d1a0ba498e93b818ffe49f',
#    'name': 'Taylor Shellfish Oyster Bar',
#    'location': {'address': '410 Occidental Ave S',
#     'lat': 47.598736913469345,
#     'lng': -122.33274587273797,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.598736913469345,
#       'lng': -122.33274587273797}],
#     'distance': 446,
#     'postalCode': '98104',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['410 Occidental Ave S',
#      'Seattle, WA 98104',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1ce941735',
#      'name': 'Seafood Restaurant',
#      'pluralName': 'Seafood Restaurants',
#      'shortName': 'Seafood',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-53d1a0ba498e93b818ffe49f-32'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '59caa279e96d0c7515ffb740',
#    'name': 'Dough Zone Dumpling House',
#    'location': {'address': '504 5th Ave S Ste 109',
#     'lat': 47.59793086989331,
#     'lng': -122.32762427885967,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.59793086989331,
#       'lng': -122.32762427885967}],
#     'distance': 463,
#     'postalCode': '98104',
#     'cc': 'US',
#     'neighborhood': 'International District',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['504 5th Ave S Ste 109',
#      'Seattle, WA 98104',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d108941735',
#      'name': 'Dumpling Restaurant',
#      'pluralName': 'Dumpling Restaurants',
#      'shortName': 'Dumplings',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dumplings_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-59caa279e96d0c7515ffb740-33'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4b26fb7cf964a520b38324e3',
#    'name': 'Il Terrazzo Carmine',
#    'location': {'address': '411 1st Ave S',
#     'crossStreet': 'btwn Jackson & King',
#     'lat': 47.59882839638095,
#     'lng': -122.33469539437857,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.59882839638095,
#       'lng': -122.33469539437857}],
#     'distance': 539,
#     'postalCode': '98104',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['411 1st Ave S (btwn Jackson & King)',
#      'Seattle, WA 98104',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d110941735',
#      'name': 'Italian Restaurant',
#      'pluralName': 'Italian Restaurants',
#      'shortName': 'Italian',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4b26fb7cf964a520b38324e3-34'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4742d96df964a520774c1fe3',
#    'name': 'Planet Java',
#    'location': {'address': '72 S Washington St',
#     'crossStreet': 'at 1st Ave S',
#     'lat': 47.60093127887959,
#     'lng': -122.33529223701342,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.60093127887959,
#       'lng': -122.33529223701342}],
#     'distance': 470,
#     'postalCode': '98104',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['72 S Washington St (at 1st Ave S)',
#      'Seattle, WA 98104',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d143941735',
#      'name': 'Breakfast Spot',
#      'pluralName': 'Breakfast Spots',
#      'shortName': 'Breakfast',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4742d96df964a520774c1fe3-35'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '5aabfe234940bc48fece464f',
#    'name': 'General Porpoise Coffee & Doughnuts',
#    'location': {'address': '401 1st Ave S',
#     'crossStreet': 'at S Jackson St',
#     'lat': 47.599112722132304,
#     'lng': -122.33432683996949,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.599112722132304,
#       'lng': -122.33432683996949}],
#     'distance': 497,
#     'postalCode': '98104',
#     'cc': 'US',
#     'neighborhood': 'Pioneer Square',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['401 1st Ave S (at S Jackson St)',
#      'Seattle, WA 98104',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d148941735',
#      'name': 'Donut Shop',
#      'pluralName': 'Donut Shops',
#      'shortName': 'Donuts',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-5aabfe234940bc48fece464f-36'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '49d3e558f964a520225c1fe3',
#    'name': 'Cherry Street Coffee House',
#    'location': {'address': '103 Cherry St',
#     'crossStreet': 'at 1st Ave',
#     'lat': 47.6027673689831,
#     'lng': -122.33415096584942,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.6027673689831,
#       'lng': -122.33415096584942}],
#     'distance': 382,
#     'postalCode': '98104',
#     'cc': 'US',
#     'neighborhood': 'Seattle Central Business District',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['103 Cherry St (at 1st Ave)',
#      'Seattle, WA 98104',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1e0931735',
#      'name': 'Coffee Shop',
#      'pluralName': 'Coffee Shops',
#      'shortName': 'Coffee Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-49d3e558f964a520225c1fe3-37'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '53643967498eff6b63587c78',
#    'name': 'The Pharmacy',
#    'location': {'address': '126 S Jackson St',
#     'crossStreet': 'under Temple Billards',
#     'lat': 47.5992749490448,
#     'lng': -122.33305345481402,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.5992749490448,
#       'lng': -122.33305345481402}],
#     'distance': 415,
#     'postalCode': '98104',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['126 S Jackson St (under Temple Billards)',
#      'Seattle, WA 98104',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d121941735',
#      'name': 'Lounge',
#      'pluralName': 'Lounges',
#      'shortName': 'Lounge',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-53643967498eff6b63587c78-38'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '543ebfd6498e299b60cf8660',
#    'name': 'Little Sheep Mongolian Hot Pot, Seattle',
#    'location': {'address': '609 S Weller St',
#     'crossStreet': '6th Ave S',
#     'lat': 47.597454046633814,
#     'lng': -122.32619062617528,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.597454046633814,
#       'lng': -122.32619062617528}],
#     'distance': 549,
#     'postalCode': '98104',
#     'cc': 'US',
#     'neighborhood': 'International District',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['609 S Weller St (6th Ave S)',
#      'Seattle, WA 98104',
#      'United States']},
#    'categories': [{'id': '52af0bd33cf9994f4e043bdd',
#      'name': 'Hotpot Restaurant',
#      'pluralName': 'Hotpot Restaurants',
#      'shortName': 'Hotpot',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '131825111'}},
#   'referralId': 'e-0-543ebfd6498e299b60cf8660-39'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4e4dd53abd4101d0d79c468e',
#    'name': 'Uwajimaya Deli',
#    'location': {'address': '600 5th Ave',
#     'lat': 47.59736400493353,
#     'lng': -122.32726686095577,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.59736400493353,
#       'lng': -122.32726686095577}],
#     'distance': 531,
#     'postalCode': '98104',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['600 5th Ave', 'Seattle, WA 98104', 'United States']},
#    'categories': [{'id': '4bf58dd8d48988d146941735',
#      'name': 'Deli / Bodega',
#      'pluralName': 'Delis / Bodegas',
#      'shortName': 'Deli / Bodega',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4e4dd53abd4101d0d79c468e-40'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '455864a4f964a520403d1fe3',
#    'name': 'Loews Hotel 1000, Seattle',
#    'location': {'address': '1000 1st Ave',
#     'lat': 47.605051,
#     'lng': -122.336105,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.605051,
#       'lng': -122.336105}],
#     'distance': 622,
#     'postalCode': '98104',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['1000 1st Ave',
#      'Seattle, WA 98104',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1fa931735',
#      'name': 'Hotel',
#      'pluralName': 'Hotels',
#      'shortName': 'Hotel',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '32743082'}},
#   'referralId': 'e-0-455864a4f964a520403d1fe3-41'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '5b4d12ccb1ec13002f690159',
#    'name': 'Amazon Go',
#    'location': {'address': '920 5th Ave',
#     'crossStreet': '5th and Marion',
#     'lat': 47.605985444645924,
#     'lng': -122.33139945825612,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.605985444645924,
#       'lng': -122.33139945825612}],
#     'distance': 478,
#     'postalCode': '98104',
#     'cc': 'US',
#     'neighborhood': 'Seattle Central Business District',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['920 5th Ave (5th and Marion)',
#      'Seattle, WA 98104',
#      'United States']},
#    'categories': [{'id': '4d954b0ea243a5684a65b473',
#      'name': 'Convenience Store',
#      'pluralName': 'Convenience Stores',
#      'shortName': 'Convenience Store',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/conveniencestore_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-5b4d12ccb1ec13002f690159-42'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '48d0079bf964a520f0511fe3',
#    'name': 'Theatre Off Jackson',
#    'location': {'address': '409 7th Ave S',
#     'lat': 47.59889822944957,
#     'lng': -122.32398871067649,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.59889822944957,
#       'lng': -122.32398871067649}],
#     'distance': 518,
#     'postalCode': '98104',
#     'cc': 'US',
# ...
#      'Seattle, WA 98101',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1ca941735',
#      'name': 'Pizza Place',
#      'pluralName': 'Pizza Places',
#      'shortName': 'Pizza',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '36946552'}},
#   'referralId': 'e-0-4a1b52eff964a520ea7a1fe3-85'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4c8ae4ef9ef0224b5c775f7b',
#    'name': 'Seattle Waterfront',
#    'location': {'address': '2711-2799 Alaskan Way',
#     'lat': 47.60639398655344,
#     'lng': -122.34112966639444,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.60639398655344,
#       'lng': -122.34112966639444}],
#     'distance': 1022,
#     'postalCode': '98121',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['2711-2799 Alaskan Way',
#      'Seattle, WA 98121',
#      'United States']},
#    'categories': [{'id': '56aa371be4b08b9a8d5734c3',
#      'name': 'Waterfront',
#      'pluralName': 'Waterfronts',
#      'shortName': 'Waterfront',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/river_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4c8ae4ef9ef0224b5c775f7b-86'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4a13ac23f964a520f9771fe3',
#    'name': 'Saba Ethiopian Cuisine',
#    'location': {'address': '110 12th Ave',
#     'crossStreet': 'at E Yesler Way',
#     'lat': 47.60204927283071,
#     'lng': -122.31672639793094,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.60204927283071,
#       'lng': -122.31672639793094}],
#     'distance': 936,
#     'postalCode': '98122',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['110 12th Ave (at E Yesler Way)',
#      'Seattle, WA 98122',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d10a941735',
#      'name': 'Ethiopian Restaurant',
#      'pluralName': 'Ethiopian Restaurants',
#      'shortName': 'Ethiopian',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ethiopian_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4a13ac23f964a520f9771fe3-87'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4339dd00f964a52034281fe3',
#    'name': 'The Hideout',
#    'location': {'address': '1005 Boren Ave',
#     'crossStreet': 'at Madison St',
#     'lat': 47.60951227498591,
#     'lng': -122.3254652798913,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.60951227498591,
#       'lng': -122.3254652798913}],
#     'distance': 886,
#     'postalCode': '98104',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['1005 Boren Ave (at Madison St)',
#      'Seattle, WA 98104',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1d4941735',
#      'name': 'Speakeasy',
#      'pluralName': 'Speakeasies',
#      'shortName': 'Speakeasy',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/secretbar_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4339dd00f964a52034281fe3-88'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4e68cd89cc3f39dbbd1d52fb',
#    'name': 'Spa at Four Seasons Hotel',
#    'location': {'address': '99 Union St',
#     'crossStreet': 'at 1st Ave',
#     'lat': 47.60744367271977,
#     'lng': -122.33934540066396,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.60744367271977,
#       'lng': -122.33934540066396}],
#     'distance': 976,
#     'postalCode': '98101',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['99 Union St (at 1st Ave)',
#      'Seattle, WA 98101',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1ed941735',
#      'name': 'Spa',
#      'pluralName': 'Spas',
#      'shortName': 'Spa',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4e68cd89cc3f39dbbd1d52fb-89'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '44d1ef56f964a52030361fe3',
#    'name': 'ACT Theatre',
#    'location': {'address': '700 Union St',
#     'crossStreet': 'at 7th Ave',
#     'lat': 47.610763429582846,
#     'lng': -122.33290463088242,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.610763429582846,
#       'lng': -122.33290463088242}],
#     'distance': 1019,
#     'postalCode': '98101',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['700 Union St (at 7th Ave)',
#      'Seattle, WA 98101',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d137941735',
#      'name': 'Theater',
#      'pluralName': 'Theaters',
#      'shortName': 'Theater',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_theater_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-44d1ef56f964a52030361fe3-90'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4cd2f6a5dd24a090364fc1d2',
#    'name': 'Paper Hammer',
#    'location': {'address': '1400 2nd Ave',
#     'crossStreet': 'at Union St',
#     'lat': 47.608381912402685,
#     'lng': -122.33799685313082,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.608381912402685,
#       'lng': -122.33799685313082}],
#     'distance': 973,
#     'postalCode': '98101',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['1400 2nd Ave (at Union St)',
#      'Seattle, WA 98101',
#      'United States']},
#    'categories': [{'id': '52f2ab2ebcbc57f1066b8b21',
#      'name': 'Stationery Store',
#      'pluralName': 'Stationery Stores',
#      'shortName': 'Stationery Store',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4cd2f6a5dd24a090364fc1d2-91'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '49e77438f964a520a2641fe3',
#    'name': 'Seattle Deli',
#    'location': {'address': '225 12th Ave S',
#     'crossStreet': 'S Main St',
#     'lat': 47.60023469456016,
#     'lng': -122.31744634924641,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.60023469456016,
#       'lng': -122.31744634924641}],
#     'distance': 903,
#     'postalCode': '98144',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['225 12th Ave S (S Main St)',
#      'Seattle, WA 98144',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d14a941735',
#      'name': 'Vietnamese Restaurant',
#      'pluralName': 'Vietnamese Restaurants',
#      'shortName': 'Vietnamese',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-49e77438f964a520a2641fe3-92'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '40b68100f964a5206e001fe3',
#    'name': 'Triple Door',
#    'location': {'address': '216 Union St',
#     'crossStreet': 'at 2nd Ave',
#     'lat': 47.60877487195221,
#     'lng': -122.33738987451225,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.60877487195221,
#       'lng': -122.33738987451225}],
#     'distance': 976,
#     'postalCode': '98101',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['216 Union St (at 2nd Ave)',
#      'Seattle, WA 98101',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1e5931735',
#      'name': 'Music Venue',
#      'pluralName': 'Music Venues',
#      'shortName': 'Music Venue',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-40b68100f964a5206e001fe3-93'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4c51cb5494790f4784aba7a1',
#    'name': 'Japonessa',
#    'location': {'address': '1400 1st Ave',
#     'crossStreet': 'at Union St',
#     'lat': 47.607970199974396,
#     'lng': -122.33876120593777,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.607970199974396,
#       'lng': -122.33876120593777}],
#     'distance': 981,
#     'postalCode': '98101',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['1400 1st Ave (at Union St)',
#      'Seattle, WA 98101',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1d2941735',
#      'name': 'Sushi Restaurant',
#      'pluralName': 'Sushi Restaurants',
#      'shortName': 'Sushi',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '53223536'}},
#   'referralId': 'e-0-4c51cb5494790f4784aba7a1-94'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '511d2f0db0ed4a4d357f263f',
#    'name': "Von's Gustobistro",
#    'location': {'address': '1225 1st Ave',
#     'crossStreet': 'at University St',
#     'lat': 47.60677627400141,
#     'lng': -122.3382968092269,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.60677627400141,
#       'lng': -122.3382968092269}],
#     'distance': 868,
#     'postalCode': '98101',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['1225 1st Ave (at University St)',
#      'Seattle, WA 98101',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d14e941735',
#      'name': 'American Restaurant',
#      'pluralName': 'American Restaurants',
#      'shortName': 'American',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-511d2f0db0ed4a4d357f263f-95'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '59ac98fb86bc494d390a32d5',
#    'name': 'Pho Bac Sup Shop',
#    'location': {'address': '1240 S Jackson St',
#     'lat': 47.59944334159577,
#     'lng': -122.31529782031112,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.59944334159577,
#       'lng': -122.31529782031112}],
#     'distance': 1080,
#     'postalCode': '98144',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['1240 S Jackson St',
#      'Seattle, WA 98144',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d14a941735',
#      'name': 'Vietnamese Restaurant',
#      'pluralName': 'Vietnamese Restaurants',
#      'shortName': 'Vietnamese',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-59ac98fb86bc494d390a32d5-96'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '40c8f600f964a520fd001fe3',
#    'name': 'The Showbox',
#    'location': {'address': '1426 1st Ave',
#     'crossStreet': 'btwn Pike & Union',
#     'lat': 47.60833139574466,
#     'lng': -122.33928564927086,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.60833139574466,
#       'lng': -122.33928564927086}],
#     'distance': 1037,
#     'postalCode': '98101',
#     'cc': 'US',
#     'neighborhood': 'Pike Place',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['1426 1st Ave (btwn Pike & Union)',
#      'Seattle, WA 98101',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1e9931735',
#      'name': 'Rock Club',
#      'pluralName': 'Rock Clubs',
#      'shortName': 'Rock Club',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_rockclub_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-40c8f600f964a520fd001fe3-97'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '47347490f964a5202b4c1fe3',
#    'name': 'Monorail Espresso',
#    'location': {'address': '510 Pike St',
#     'crossStreet': 'at 5th Ave',
#     'lat': 47.610827841360624,
#     'lng': -122.33504799148172,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.610827841360624,
#       'lng': -122.33504799148172}],
#     'distance': 1080,
#     'postalCode': '98101',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['510 Pike St (at 5th Ave)',
#      'Seattle, WA 98101',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1e0931735',
#      'name': 'Coffee Shop',
#      'pluralName': 'Coffee Shops',
#      'shortName': 'Coffee Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-47347490f964a5202b4c1fe3-98'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '51d9cb4d498e71691005418d',
#    'name': 'Ellenos Real Greek Yogurt',
#    'location': {'address': '1500 Pike St, #12',
#     'crossStreet': 'Pike Place & Pike Street',
#     'lat': 47.60884772199345,
#     'lng': -122.34047600660855,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 47.60884772199345,
#       'lng': -122.34047600660855}],
#     'distance': 1142,
#     'postalCode': '98101',
#     'cc': 'US',
#     'city': 'Seattle',
#     'state': 'WA',
#     'country': 'United States',
#     'formattedAddress': ['1500 Pike St, #12 (Pike Place & Pike Street)',
#      'Seattle, WA 98101',
#      'United States']},
#    'categories': [{'id': '512e7cae91d4cbb4e5efe0af',
#      'name': 'Frozen Yogurt Shop',
#      'pluralName': 'Frozen Yogurt Shops',
#      'shortName': 'Yogurt',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/frozenyogurt_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-51d9cb4d498e71691005418d-99'}]

# %%
# Print selected Venue Name results, to verify the object referencing:
# results['response']['groups'][0]['items'][0]['venue']['name']  --> 'SFJazz Center'
for i in range(20):
    print(results['response']['groups'][0]['items'][i]['venue']['name'])
# Out:
# Il Corvo
# Flatstick Pub
# Elm Coffee Roasters
# Biscuit B*tch
# Tat's Delicatessen
# Tsukushinbo
# Cherry Street Public House
# Columbia Tower Club
# Smith Tower
# Juicy Cafe
# Good Bar
# Smith Tower Observation Deck
# Damn the Weather
# The Bar Shoppe
# Delicatus
# Maneki
# Top Pot Doughnuts
# Salumi
# Caffè Umbria
# Zeitgeist Kunst & Kaffee

# %%
# Now we clean the JSON object and structure it into a pandas dataframe.
search_query_SEA = 'venues'
venues_SEA = results['response']['groups'][0]['items']
nearby_venues_SEA = json_normalize(venues_SEA)     # flatten JSON
nearby_venues_SEA.head()
# Out:
#    reasons.count                                      reasons.items  \
# 0              0  [{'summary': 'This spot is popular', 'type': '...
# 1              0  [{'summary': 'This spot is popular', 'type': '...
# 2              0  [{'summary': 'This spot is popular', 'type': '...
# 3              0  [{'summary': 'This spot is popular', 'type': '...
# 4              0  [{'summary': 'This spot is popular', 'type': '...
#
#                        referralId  \
# 0  e-0-4db71ec1a86ed8d46c6e179c-0
# 1  e-0-56b101bb498e4905510a5798-1
# 2  e-0-545803de498e7e758ac5605e-2
# 3  e-0-5762cc9ccd1085a720b1433e-3
# 4  e-0-455c500ef964a5206e3d1fe3-4
#
#                                     venue.categories venue.delivery.id  \
# 0  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...               NaN
# 1  [{'id': '56aa371ce4b08b9a8d57356c', 'name': 'B...               NaN
# 2  [{'id': '4bf58dd8d48988d1e0931735', 'name': 'C...               NaN
# 3  [{'id': '4bf58dd8d48988d143941735', 'name': 'B...               NaN
# 4  [{'id': '4bf58dd8d48988d1c5941735', 'name': 'S...               NaN
#
#   venue.delivery.provider.icon.name venue.delivery.provider.icon.prefix  \
# 0                               NaN                                 NaN
# 1                               NaN                                 NaN
# 2                               NaN                                 NaN
# 3                               NaN                                 NaN
# 4                               NaN                                 NaN
#
#   venue.delivery.provider.icon.sizes venue.delivery.provider.name  \
# 0                                NaN                          NaN
# 1                                NaN                          NaN
# 2                                NaN                          NaN
# 3                                NaN                          NaN
# 4                                NaN                          NaN
#
#   venue.delivery.url                  venue.id        venue.location.address  \
# 0                NaN  4db71ec1a86ed8d46c6e179c                  217 James St
# 1                NaN  56b101bb498e4905510a5798                 240 2nd Ave S
# 2                NaN  545803de498e7e758ac5605e  240 2nd Avenue Ext S Ste 103
# 3                NaN  5762cc9ccd1085a720b1433e                   621 3rd Ave
# 4                NaN  455c500ef964a5206e3d1fe3                159 Yesler Way
#
#   venue.location.cc venue.location.city venue.location.country  \
# 0                US             Seattle          United States
# 1                US             Seattle          United States
# 2                US             Seattle          United States
# 3                US             Seattle          United States
# 4                US             Seattle          United States
#
#   venue.location.crossStreet  venue.location.distance  \
# 0         btwn 2nd & 3rd Ave                      215
# 1                       Main                      249
# 2                        NaN                      239
# 3       James St & Cherry St                      254
# 4                 at 2nd Ave                      241
#
#                      venue.location.formattedAddress  \
# 0  [217 James St (btwn 2nd & 3rd Ave), Seattle, W...
# 1  [240 2nd Ave S (Main), Seattle, WA 98104, Unit...
# 2  [240 2nd Avenue Ext S Ste 103, Seattle, WA 981...
# 3  [621 3rd Ave (James St & Cherry St), Seattle, ...
# 4  [159 Yesler Way (at 2nd Ave), Seattle, WA 9810...
#
#                        venue.location.labeledLatLngs  venue.location.lat  \
# 0  [{'label': 'display', 'lat': 47.60252187796595...           47.602522
# 1  [{'label': 'display', 'lat': 47.60022, 'lng': ...           47.600220
# 2  [{'label': 'display', 'lat': 47.60015237080675...           47.600152
# 3  [{'label': 'display', 'lat': 47.603237, 'lng':...           47.603237
# 4  [{'label': 'display', 'lat': 47.60190101610654...           47.601901
#
#    venue.location.lng venue.location.neighborhood venue.location.postalCode  \
# 0         -122.331952                         NaN                     98104
# 1         -122.331310              Pioneer Square                     98104
# 2         -122.330944                         NaN                     98104
# 3         -122.332010                         NaN                     98104
# 4         -122.332423              Pioneer Square                     98104
#
#   venue.location.state           venue.name  venue.photos.count  \
# 0                   WA             Il Corvo                   0
# 1                   WA        Flatstick Pub                   0
# 2                   WA  Elm Coffee Roasters                   0
# 3                   WA        Biscuit B*tch                   0
# 4                   WA   Tat's Delicatessen                   0
#
#   venue.photos.groups venue.venuePage.id
# 0                  []                NaN
# 1                  []          154127947
# 2                  []                NaN
# 3                  []                NaN
# 4                  []                NaN
